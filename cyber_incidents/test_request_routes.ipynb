# %%
import requests
url = "http://127.0.0.1:5000/"

# %% [markdown]
# D'abord ouvrir app.py et lancer la fonction dans un terminal spécifique
#
# Puis ensuite toutes les fonctions créés dans /routes/ pour interagir avec la BDD sont testé ici ci-dessous.
# Il suffit de modifier les données voulut ou d'en tester d'autres
#
# !!Attention!!  lorsqu'on ajoute qq à la base de données il est nécessaire de le supprimer avant de le 'réajouter' sinon on peut avoir une erreur de contrainte  d'unicité

# %% [markdown]
# On a utilisé INSERT OR IGNORE donc toutes ces fonctions ont déjà été implémenté et fonctionne encore mais par exemple karl est déjà dans la base de données

# %% [markdown]
# Les différents agents et leurs mdp pour pouvoir créer des token:
#
# hubert:666
#
# charles:123
#
# François:438
#
# henriette:999
#
# karl:117
#
# léopold:384
#
# mehdi:222

# %% [markdown]
# ON TESTE LA FONCTION LOGIN
#
#
# cela permet de créer le token pour accéder à toutes les fonctions qui nécessitent une sécurité

# %%
requete=requests.post(url+"login/login",json={"username":"karl","password":"117"})
A=requete.json()
token=A['token']
print(A)
# Out:
# {'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6ImthcmwiLCJleHAiOjE3Mjk0MzAxMTN9.9Zv0c6_P_ad5knbD2D2NWU7FuhhJECrE-9j6KHZz5wc'}

# %% [markdown]
# ON TESTE LES FONCTIONS DE ROUTES/DATA

# %%
response1 = requests.get(url+"data/responses")
response1.json()
# Out:
# {'responses': ['https://www.theregister.co.uk/2020/02/14/austria_foreign_ministry_hack_turla_group_allegs/',
#   'https://www.bleepingcomputer.com/news/security/hacker-group-catfishes-israeli-soldiers-into-installing-mobile-rat/',
#   'https://us-cert.cisa.gov/ncas/analysis-reports/ar20-133a',
#   'https://www.ynet.co.il/article/rJrCqmAkw',
#   'https://www.gov.pl/web/sluzby-specjalne/atak-dezinformacyjny-na-polske',
#   'https://www.ynet.co.il/article/rJrCqmAkw',
#   'https://us-cert.cisa.gov/ncas/alerts/aa20-258a',
#   'https://www.politico.com/f/?id=00000173-76e6-d36e-abff-7ffe63dc0000',
#   'https://www.reuters.com/article/us-taiwan-cyber-china/taiwan-says-china-behind-cyberattacks-on-government-agencies-emails-idUSKCN25F0JK',
#   'https://us-cert.cisa.gov/ncas/alerts/aa20-259a',
#   'https://www.cyberscoop.com/german-intelligence-memo-berserk-bear-critical-infrastructure/',
#   'https://www.jpost.com/breaking-news/cyber-attack-targets-iranian-port-near-strait-of-hormuz-627616',
# ...

# %%
response2 = requests.get(url+"data/targets",headers={'Authorization':token})
response2.json()
# Out:
# {'targets': ['Austrian Foreign Ministry',
#   'Employees of the U.S. government',
#   '',
#   'Israeli Defense Forces (IDF) soldiers',
#   'U.S. government agencies',
#   'U.S. companies',
#   'Saudi Arabian citizens in the Untied States',
#   'Global financial institutions',
#   'Iranian expats and dissidents',
#   'North American and Israeli organizations',
#   'Burisma',
#   'Ben Hubbard',
#   'Israel',
#   'Arabic speakers in Syria and surrounding region',
#   'Defense companies',
#   'Private companies in numerous countries',
#   'Poland’s War Studies University',
#   'Bapco',
#   'Vatican City',
#   'Pontifical Institute for Foreign Missions',
#   'Hong Kong Study Mission to China',
#   'Japanese',
#   'Russian',
#   'and South Korean civil society',
#   'private sector',
#   'and government entities.',
#   'Infrastructure used by foreign-based cybercriminals',
#   'Taiwanese government agencies and email accounts',
#   'The U.S. electrical grid',
# ...

# %%
response3 = requests.get(url+"data/attackers",headers={'Authorization':token})
response3.json()
# Out:
# {'attackers': ['Turla',
#   'Konni Group',
#   '',
#   'APT-C-23',
#   'Fox Kitten',
#   'Government of Saudi Arabia',
#   'Hidden Cobra',
#   'Also known as Parasite, UNC757, and Fox Kitten.',
#   'APT 28',
#   'KINGDOM',
#   'Believed to be the work of the Iranian government.',
#   'Syrian Electronic Army',
#   'Lazarus Group',
#   'APT 34, possibly APT 33/APT 39.',
#   'Russia',
#   'Pioneer Kitten',
#   'APT 34',
#   'NOTE: Some Moonlight Maze tooling has also been referred to as “Storm Cloud.” There is no known connection.',
#   'RedDelta',
#   'Tonto Team',
#   'Australian Signals Directorate',
#   'APT 33',
#   'Believed to be Lazarus Group',
#   'Believed to be the work of the Chinese government.\xa0',
#   'Bronze Butler',
#   'Storm Cloud',
#   'Guangdong State Security Department (GSSD) of China’s Ministry of State Security (MSS)',
#   'Chinese government',
#   'BlackTech',
#   'Chafer\xa0',
#   'Iranian government',
#   'Vicious Panda',
#   'Crouching Yeti',
# ...

# %%
response4 = requests.get(url+"data/sources",headers={'Authorization':token})
response4.json()
# Out:
# {'sources': ['https://www.theregister.co.uk/2020/02/14/austria_foreign_ministry_hack_turla_group_allegs/',
#   'https://unit42.paloaltonetworks.com/the-fractured-statue-campaign-u-s-government-targeted-in-spear-phishing-attacks/#Attribution',
#   'https://www.minister.defence.gov.au/minister/lreynolds/media-releases/offensive-against-covid-19-cyber-criminals',
#   'https://www.bleepingcomputer.com/news/security/hacker-group-catfishes-israeli-soldiers-into-installing-mobile-rat/',
#   'https://www.cybersafe.news/fbi-warns-about-iranian-hacking-group-attacking-f5-networking-devices/',
#   'https://www.theguardian.com/world/2020/mar/29/revealed-saudis-suspected-of-phone-spying-campaign-in-us',
#   'https://www.cyberscoop.com/north-korea-hacking-hidden-cobra-dhs-fbi/',
#   'https://www.crowdstrike.com/blog/who-is-pioneer-kitten/',
#   'https://www.bbc.com/news/world-us-canada-51103556',
# ...

# %% [markdown]
# ON TESTE LES FONCTIONS DE INCIDENTS

# %%
response4 = requests.get(url+"incidents/1041",headers={'Authorization':token})
response4.json()
# Out:
# {'ID_attackers': 2041,
#  'ID_attacks': 1041,
#  'confirmation': 'Yes',
#  'date': '5/26/2020',
#  'description': 'Hackers used supply chain vulnerabilities to access German critical infrastructure companies’ information technology (IT) systems.',
#  'title': 'Targeting of German critical infrastructure owners',
#  'type': 'Espionage',
#  'username': None}

# %%
response4 = requests.post(url+"incidents/1001/assign",json={"username":"hubert"},headers={'Authorization':token})
response4.json()
# Out:
# {'message': 'Done'}

# %%
response4 = requests.post(url+"incidents/1001/add",json={"source":"azertyu","nameV":"Israel"},headers={'Authorization':token})
response4.json()
# Out:
# {'message': 'Done'}

# %%
response4=requests.post(url+"incidents/1001/remove",json={"nameV":"Israel","source":"azertyu"},headers={'Authorization':token})
response4.json()
# Out:
# {'message': 'Done'}

# %%
response4=requests.patch(url+"incidents/1001",json={"description":"voici la nouvelle description"},headers={'Authorization':token})
response4.json()
# Out:
# {'message': 'Done'}

# %% [markdown]
# ON TESTE LES FONCTIONS DE AGENTS

# %%
requete=requests.get(url+"agents/",headers={'Authorization':token})
requete.json()
# Out:
# {'agents': ['François',
#   'charles',
#   'henriette',
#   'hubert',
#   'karl',
#   'léopold',
#   'mehdi']}

# %%
requete=requests.get(url+"agents/charles",headers={'Authorization':token})
requete.json()
# Out:
# {'password': 'JDJiJDEyJFEwTXhJZ3JoOHhpLktKRXJHWUI0Lk9DczBJbEpSYkZWSlFiSFlqS3dlN0RlR29wUlRmL2tt',
#  'username': 'charles'}

# %%
requete=requests.patch(url+"agents/charles",json={"password":"123"},headers={'Authorization':token})
requete.json()
# Out:
# {'message': 'Password successfully updated'}

# %%
requete=requests.post(url+"agents/",json={"username":"karl","password":"456"},headers={'Authorization':token})
requete.json()
# Out:
# {'message': 'Done'}
