# %%
import db.agents
import db.attackers
import db.incidents
import db.responses
import db.sources
import db.targets
from pprint import pprint
from db import get_db_connexion, close_db_connexion

# %% [markdown]
# Toutes les fonctions du module /db/ sont testés ici
#
# celles du module /routes/ sont testés dans le notebook suivant.

# %% [markdown]
# Les différents agents et leurs mdp pour pouvoir créer des token:
#
# hubert:666
#
# charles:123
#
# François:438
#
# henriette:999
#
# karl:117
#
# léopold:384
#
# mehdi:222

# %% [markdown]
# test fonctions agents

# %%
conn = get_db_connexion()
cursor = conn.cursor()
agent = {"username": "henriette", "password": "999"}
if db.agents.insert_agent(agent, cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
agent=db.agents.get_agent("mehdi",cursor)
print("on affiche l'agent mehdi seul avec succès",agent)
conn.close()
# Out:
# on affiche l'agent mehdi seul avec succès {'username': 'mehdi', 'incidents': [], 'password': b'$2b$12$pD4HRO/00.JyTzizdhouEuGOVAPJeVpkQoHtlmGb6tjBaF7DEnnq.'}

# %%
conn = get_db_connexion()
cursor = conn.cursor()
agents = db.agents.get_agents(cursor)
print("Agents in database:", [dict(agent) for agent in agents])
conn.close()
# Out:
# Agents in database: [{'username': 'François'}, {'username': 'charles'}, {'username': 'henriette'}, {'username': 'hubert'}, {'username': 'karl'}, {'username': 'léopold'}, {'username': 'mehdi'}]

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.agents.update_password("henriette","999", cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# Le mot de passe de l'agent 'henriette' a été mis à jour.
# sucess

# %% [markdown]
# test fonctions attackers

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.attackers.insert_attacker("Les_méchants","china",cursor):
    print("success")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# success

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.attackers.update_attacker_sponsor("Les_méchants","japan",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# Le pays de l'attaquant 'Les_méchants' a été mis à jour.
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
rows=db.attackers.get_attackers(cursor)
result = [dict(row) for row in rows]
for row in result:
    print(list(row.values()))
conn.close()
# Out:
# ['']
# ['A variant of Lucky Cat for Mac computers']
# ['APT 10']
# ['APT 17 and Bronze Butler']
# ['APT 20']
# ['APT 28']
# ['APT 3']
# ['APT 30']
# ['APT 33']
# ['APT 34']
# ['APT 34, possibly APT 33/APT 39.']
# ['APT 36']
# ['APT 40']
# ['APT 41']
# ['APT-C-23']
# ['APTs associated with Beijing']
# ['Allosh, Syrian Government\xa0']
# ['Also known as APT 1, Comment Crew, Comment Panda, TG-8223, Group 3, GIF89a, and Byzantine Candor']
# ['Also known as APT 2, PLA Unit 61486, and TG-6952']
# ['Also known as APT 21']
# ['Also known as APT 29 and Cozy Bear.\xa0Estonian intelligence services associate this group with the Russian Federal Security Service (FSB) and Foreign Intelligence Service (SVR).']
# ['Also known as APT 31 and Judgement Panda.']
# ['Also known as APT 32']
# ['Also known as AridViper and\xa0Desert Falcon.']
# ['Also known as Billbug and Lotus Blossom.']
# ['Also known as Bronze President.']
# ...

# %% [markdown]
# test fonctions responses

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.responses.insert_response("","voici_le_lien",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
cursor.execute("""DELETE FROM Response WHERE source_of_response=? """,['voici_le_lien'])
conn.commit()
conn.close()

# %%
conn = get_db_connexion()
cursor = conn.cursor()
rows=db.responses.get_response([1041],cursor)
result = [dict(row) for row in rows]
for row in result:
    print(row)
conn.close()
# Out:
# {'ID_response': 3041, 'type_response': 'Confirmation', 'source_of_response': 'https://www.cyberscoop.com/german-intelligence-memo-berserk-bear-critical-infrastructure/', 'ID_attacks': 1041}

# %% [markdown]
# test fonctions sources

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.sources.insert_source("voici_le_lien",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
cursor.execute("""DELETE FROM Source WHERE source=? """,['voici_le_lien'])
conn.commit()
conn.close()

# %%
conn = get_db_connexion()
cursor = conn.cursor()
rows=db.sources.get_sources(cursor)
result = [dict(row) for row in rows]
for row in result:
    print(row)
conn.close()
# Out:
# {'ID_info': 4000, 'type_source': 'Confirmation', 'source': 'https://www.theregister.co.uk/2020/02/14/austria_foreign_ministry_hack_turla_group_allegs/', 'ID_attacks': 1000, 'ID_response': 3000}
# {'ID_info': 4001, 'type_source': None, 'source': 'https://unit42.paloaltonetworks.com/the-fractured-statue-campaign-u-s-government-targeted-in-spear-phishing-attacks/#Attribution', 'ID_attacks': 1001, 'ID_response': None}
# {'ID_info': 4002, 'type_source': None, 'source': 'https://www.minister.defence.gov.au/minister/lreynolds/media-releases/offensive-against-covid-19-cyber-criminals', 'ID_attacks': 1002, 'ID_response': None}
# {'ID_info': 4003, 'type_source': 'Hack Back', 'source': 'https://www.bleepingcomputer.com/news/security/hacker-group-catfishes-israeli-soldiers-into-installing-mobile-rat/', 'ID_attacks': 1003, 'ID_response': 3003}
# ...

# %% [markdown]
# test fonctions targets

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.targets.insert_target("nom_de_la_target","",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
cursor.execute("""DELETE FROM Victim WHERE nameV=? """,['nom_de_la_target'])
conn.commit()
conn.close()

# %%
conn = get_db_connexion()
cursor = conn.cursor()
rows=db.targets.get_targets(cursor)
result = [dict(row) for row in rows]
for row in result:
    print(row)
conn.close()
# Out:
# {'ID_victim': 1, 'nameV': 'Austrian Foreign Ministry', 'category': 'Government'}
# {'ID_victim': 3, 'nameV': 'Employees of the U.S. government', 'category': 'Government'}
# {'ID_victim': 7, 'nameV': 'Israeli Defense Forces (IDF) soldiers', 'category': 'Military'}
# {'ID_victim': 9, 'nameV': 'U.S. government agencies', 'category': 'Government, Private sector'}
# {'ID_victim': 11, 'nameV': 'U.S. companies', 'category': 'Government, Private sector'}
# {'ID_victim': 13, 'nameV': 'Saudi Arabian citizens in the Untied States', 'category': 'Private sector'}
# {'ID_victim': 15, 'nameV': 'Global financial institutions', 'category': 'Private sector'}
# {'ID_victim': 17, 'nameV': 'Iranian expats and dissidents', 'category': 'Civil society, Private sector, Government'}
# {'ID_victim': 19, 'nameV': 'North American and Israeli organizations', 'category': 'Civil society, Private sector, Government'}
# {'ID_victim': 21, 'nameV': 'Burisma', 'category': 'Private sector'}
# ...

# %% [markdown]
# test fonctions incidents

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.incidents.insert_incident("name","10/06/2007","description","espionnage","isConfirmed","source_links","attacker_affiliation","target_name","response_type",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# sucess

# %% [markdown]
# Le script suivant a pour but de supprimer l'attaque que l'on vient d'ajouter et on supprime aussi tout ce qui y est affilié
# Pour enlever par exemple l'attaque nommé 'name' ci dessus il faut enlever les commentaires du script ci dessous (ctrl+/) et lancer le script

# %%
# conn = get_db_connexion()
# cursor = conn.cursor()
# cursor.execute("""SELECT ID_victim FROM Victim WHERE nameV=? """,['target_name'])
# requete=cursor.fetchone()[0]
# cursor.execute("""DELETE FROM Attacks WHERE title=? """,['name'])
# cursor.execute("""DELETE FROM Affiliation WHERE affiliation_name=? """,['attacker_affiliation'])
# cursor.execute("""DELETE FROM Attackers WHERE affiliation_name=? """,['attacker_affiliation'])
# cursor.execute("""DELETE FROM Source WHERE source=? """,['source_links'])
# cursor.execute("""DELETE FROM Attackers_Victim WHERE ID_victim=? """,(requete,))
# cursor.execute("""DELETE FROM Attacks_Victim WHERE ID_victim=? """,(requete,))
# cursor.execute("""DELETE FROM Victim WHERE ID_victim=? """,(requete,))
# conn.commit()
# conn.close()

# %%
conn = get_db_connexion()
cursor = conn.cursor()
rows=db.incidents.get_incident("Unnamed Actor",cursor)
result = [dict(row) for row in rows]
for row in result:
    print(list(row.values()))
conn.close()
conn.close()
# Out:
# [1309, '4/13/2016', 'Unnamed Actor', 'This threat actor compromises civil society groups the Chinese Communist Party views as hostile to its interests, such as Tibetan, Uyghur, Hong Kong, and Taiwanese activist. The threat actor also targeted the Myanmar electoral commission.', 'Espionage', 'No', 2309, None]

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.incidents.update_incident_attacker("name","azerty",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# Le nom de l'attaquant de l'attaque 'name' a été mis à jour.
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.incidents.update_incident_response("name","azerty",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# la réponse de l'attaque 'name' a été mis à jour.
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.incidents.add_incident_target("name","Burisma",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# Victim 'Burisma' is already associated with the attack 'name'.
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.incidents.remove_incident_target("name","Israel",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# Victim 'Israel' is not associated with the attack 'name'.
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.incidents.add_incident_source("name","on_ajoute_un_lien",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# Source 'on_ajoute_un_lien' added to attack 'name' with Source ID 6506.
# sucess

# %%
conn = get_db_connexion()
cursor = conn.cursor()
if db.incidents.remove_incident_source("name","on_ajoute_un_lien",cursor):
    print("sucess")
else:
    print("fail")
conn.commit()
conn.close()
# Out:
# Source 'on_ajoute_un_lien' removed from attack 'name'.
# sucess
